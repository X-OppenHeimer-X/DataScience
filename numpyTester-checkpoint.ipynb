# %%
import pandas as pd

# %%
variable=pd.read_csv(r"C:\Users\tahuj\Desktop\airline-safety.csv")

# %%
variable.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14
# 0                      0                 0
# 1                      1                88
# 2                      0                 0
# ...

# %%
df=pd.DataFrame({'ID':[100,101,102],'NAME':["Ashish","Manish","Somesh"],'COLOR':['Yellow','Blue','Green']},columns=["ID","NAME","COLOR"],index=['1','2','3'])

# %%
df
# Out:
#     ID    NAME   COLOR
# 1  100  Ashish  Yellow
# 2  101  Manish    Blue
# 3  102  Somesh   Green

# %%
df.head(3)
# Out:
#     ID    NAME   COLOR
# 1  100  Ashish  Yellow
# 2  101  Manish    Blue
# 3  102  Somesh   Green

# %%
variable.loc[0:34,['fatal_accidents_85_99','fatalities_85_99','fatalities_00_14']]
# Out:
#     fatal_accidents_85_99  fatalities_85_99  fatalities_00_14
# 0                       0                 0                 0
# 1                      14               128                88
# 2                       0                 0                 0
# 3                       1                64                 0
# 4                       0                 0                 0
# 5                       4                79               337
# 6                       1               329               158
# 7                       0                 0                 7
# 8                       0                 0                88
# 9                       2                50                 0
# 10                      1                 1                 0
# 11                      5               101               416
# 12                      0                 0                 0
# 13                      3               323                 0
# ...
